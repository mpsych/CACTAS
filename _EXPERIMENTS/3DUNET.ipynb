# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv3D, Input, MaxPooling3D, Dropout, concatenate, UpSampling3D
import tensorflow as tf
import os

def Unet3D(inputs,num_classes):
    x=inputs
    conv1 = Conv3D(8, 3, activation = 'relu', padding = 'same',data_format="channels_last")(x)
    conv1 = Conv3D(8, 3, activation = 'relu', padding = 'same')(conv1)
    pool1 = MaxPooling3D(pool_size=(2, 2, 2))(conv1)
    conv2 = Conv3D(16, 3, activation = 'relu', padding = 'same')(pool1)
    conv2 = Conv3D(16, 3, activation = 'relu', padding = 'same')(conv2)
    pool2 = MaxPooling3D(pool_size=(2, 2, 2))(conv2)
    conv3 = Conv3D(32, 3, activation = 'relu', padding = 'same')(pool2)
    conv3 = Conv3D(32, 3, activation = 'relu', padding = 'same')(conv3)
    pool3 = MaxPooling3D(pool_size=(2, 2, 2))(conv3)
    conv4 = Conv3D(64, 3, activation = 'relu', padding = 'same')(pool3)
    conv4 = Conv3D(64, 3, activation = 'relu', padding = 'same')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling3D(pool_size=(2, 2, 2))(drop4)

    conv5 = Conv3D(128, 3, activation = 'relu', padding = 'same')(pool4)
    conv5 = Conv3D(128, 3, activation = 'relu', padding = 'same')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv3D(64, 2, activation = 'relu', padding = 'same')(UpSampling3D(size = (2,2,2))(drop5))
    merge6 = concatenate([drop4,up6],axis=-1)
    conv6 = Conv3D(64, 3, activation = 'relu', padding = 'same')(merge6)
    conv6 = Conv3D(64, 3, activation = 'relu', padding = 'same')(conv6)

    up7 = Conv3D(32, 2, activation = 'relu', padding = 'same')(UpSampling3D(size = (2,2,2))(conv6))
    merge7 = concatenate([conv3,up7],axis=-1)
    conv7 = Conv3D(32, 3, activation = 'relu', padding = 'same')(merge7)
    conv7 = Conv3D(32, 3, activation = 'relu', padding = 'same')(conv7)

    up8 = Conv3D(16, 2, activation = 'relu', padding = 'same')(UpSampling3D(size = (2,2,2))(conv7))
    merge8 = concatenate([conv2,up8],axis=-1)
    conv8 = Conv3D(16, 3, activation = 'relu', padding = 'same')(merge8)
    conv8 = Conv3D(16, 3, activation = 'relu', padding = 'same')(conv8)

    up9 = Conv3D(8, 2, activation = 'relu', padding = 'same')(UpSampling3D(size = (2,2,2))(conv8))
    merge9 = concatenate([conv1,up9],axis=-1)
    conv9 = Conv3D(8, 3, activation = 'relu', padding = 'same')(merge9)
    conv9 = Conv3D(8, 3, activation = 'relu', padding = 'same')(conv9)
    conv10 = Conv3D(1, 1, activation = 'sigmoid')(conv9)
    model = Model(inputs=inputs, outputs = conv10)
    #model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model
# Out:
# 2023-01-29 22:43:38.480577: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
def dice_coe(y_true,y_pred, loss_type='jaccard', smooth=1.):

    y_true_f = tf.reshape(y_true,[-1])
    y_pred_f = tf.reshape(y_pred,[-1])

    intersection = tf.reduce_sum(y_true_f * y_pred_f)

    if loss_type == 'jaccard':
        union = tf.reduce_sum(tf.square(y_pred_f)) + tf.reduce_sum(tf.square(y_true_f))

    elif loss_type == 'sorensen':
        union = tf.reduce_sum(y_pred_f) + tf.reduce_sum(y_true_f)

    else:
        raise ValueError("Unknown `loss_type`: %s" % loss_type)

    return (2. * intersection + smooth) / (union + smooth)
def dice_loss(y_true,y_pred, loss_type='jaccard', smooth=1.):

    y_true_f = tf.cast(tf.reshape(y_true,[-1]),tf.float32)
    y_pred_f =tf.cast(tf.reshape(y_pred,[-1]),tf.float32)

    intersection = tf.reduce_sum(y_true_f * y_pred_f)

    if loss_type == 'jaccard':
        union = tf.reduce_sum(tf.square(y_pred_f)) + tf.reduce_sum(tf.square(y_true_f))

    elif loss_type == 'sorensen':
        union = tf.reduce_sum(y_pred_f) + tf.reduce_sum(y_true_f)

    else:
        raise ValueError("Unknown `loss_type`: %s" % loss_type)

    return (1-(2. * intersection + smooth) / (union + smooth))

# %%
input = tf.keras.Input(shape=(128, 512,512,1), name='CT')
m = Unet3D(input, 1)
# Out:
# 2023-01-29 22:43:49.987693: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2023-01-29 22:43:50.088992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-01-29 22:43:50.089030: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-29 22:43:50.092432: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2023-01-29 22:43:50.092465: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2023-01-29 22:43:50.093390: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2023-01-29 22:43:50.093738: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2023-01-29 22:43:50.094325: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2023-01-29 22:43:50.095118: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2023-01-29 22:43:50.095395: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2023-01-29 22:43:50.102777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-29 22:43:50.103410: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-29 22:43:50.106156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:47:00.0 name: A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.59GiB deviceMemoryBandwidth: 1.41TiB/s
# 2023-01-29 22:43:50.114395: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2023-01-29 22:43:50.114420: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2023-01-29 22:43:50.705538: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2023-01-29 22:43:50.705590: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2023-01-29 22:43:50.705596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2023-01-29 22:43:50.718371: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 38425 MB memory) -> physical GPU (device: 0, name: A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0)

# %%
TRAIN_CLASSIFY_LEARNING_RATE =1e-4
#TRAIN_CLASSIFY_LOSS=tf.keras.losses.binary_crossentropy()
OPTIMIZER=tf.keras.optimizers.Adam(lr=TRAIN_CLASSIFY_LEARNING_RATE,epsilon=1e-5)
# Out:
# /home/daniel.haehn/miniconda3/envs/CTF25/lib/python3.9/site-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:374: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
m.compile(optimizer=OPTIMIZER, loss=[dice_loss], metrics=['accuracy',dice_coe])

# %%
m.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# CT (InputLayer)                 [(None, 128, 512, 51 0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 128, 512, 512 224         CT[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 128, 512, 512 1736        conv3d[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (None, 64, 256, 256, 0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 64, 256, 256, 3472        max_pooling3d[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 64, 256, 256, 6928        conv3d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 32, 128, 128, 0           conv3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 32, 128, 128, 13856       max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 32, 128, 128, 27680       conv3d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 16, 64, 64, 3 0           conv3d_5[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 16, 64, 64, 6 55360       max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 16, 64, 64, 6 110656      conv3d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 64, 64, 6 0           conv3d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 8, 32, 32, 64 0           dropout[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 8, 32, 32, 12 221312      max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 8, 32, 32, 12 442496      conv3d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 32, 32, 12 0           conv3d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling3d (UpSampling3D)    (None, 16, 64, 64, 1 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 16, 64, 64, 6 65600       up_sampling3d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 64, 64, 1 0           dropout[0][0]
#                                                                  conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 16, 64, 64, 6 221248      concatenate[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 16, 64, 64, 6 110656      conv3d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 32, 128, 128, 0           conv3d_12[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 32, 128, 128, 16416       up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 128, 128, 0           conv3d_5[0][0]
#                                                                  conv3d_13[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 32, 128, 128, 55328       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 32, 128, 128, 27680       conv3d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 64, 256, 256, 0           conv3d_15[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 64, 256, 256, 4112        up_sampling3d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 256, 256, 0           conv3d_3[0][0]
#                                                                  conv3d_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 64, 256, 256, 13840       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 64, 256, 256, 6928        conv3d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 128, 512, 512 0           conv3d_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 128, 512, 512 1032        up_sampling3d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 512, 512 0           conv3d_1[0][0]
#                                                                  conv3d_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 128, 512, 512 3464        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 128, 512, 512 1736        conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 128, 512, 512 9           conv3d_21[0][0]
# ==================================================================================================
# Total params: 1,411,769
# Trainable params: 1,411,769
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import cactas as C
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
# DATAPATH = '/home/d/Dropbox/RESEARCH/CAROTID/DATA/Nathan Arnett Calcification/'
DATAPATH = '/raid/mpsych/CACTAS/DATA/Nathan Arnett Calcification/'

# %%
DATASETS = sorted([v for v in os.listdir(DATAPATH) if os.path.isdir(DATAPATH + v)])

images = []
labels = []

for i,d in enumerate(DATASETS[0:3]):
    
    # ignore DICOM 12 since we have DICOM 12-checked
    if d == 'DICOM 12' or d == 'DICOM 61' or d == 'DICOM 51':
        continue
    
    image_with_header, label_with_header = C.Util.load(i, datapath=DATAPATH, with_header=True)

    spacing = [image_with_header[1]['space directions'][0,0],
               image_with_header[1]['space directions'][1,1],
               1]
#                image_with_header[1]['space directions'][2,2]]
#
#     print(d, spacing)
    
    image = image_with_header[0]
    label = label_with_header[0]
    
    ###
    c_image = C.Util.normalize(image[:,:,image.shape[2]//2-64:image.shape[2]//2+64])
    c_label = C.Util.binarize(label[:,:,image.shape[2]//2-64:image.shape[2]//2+64])
    
    images.append(c_image)
    labels.append(c_label)

# %%
images_a = np.zeros((len(images), images[0].shape[0], images[0].shape[1], images[0].shape[2]), dtype=images[0].dtype)
for i,j in enumerate(images):
    images_a[i] = images[i]
    
labels_a = np.zeros((len(labels), labels[0].shape[0], labels[0].shape[1], labels[0].shape[2]), dtype=labels[0].dtype)
for i,j in enumerate(labels):
    labels_a[i] = labels[i]

# %%
images_a = np.swapaxes(images_a.astype(np.float16), 1,3)
labels_a = np.swapaxes(labels_a.astype(np.float16), 1,3)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((images_a, labels_a))
BATCH_SIZE = 2
SHUFFLE_BUFFER_SIZE = 5

train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)

# %%
history = m.fit(train_dataset, epochs=1000)
# Out:
# Epoch 1/1000
# 2023-01-29 22:47:28.907895: W tensorflow/core/common_runtime/bfc_allocator.cc:456] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.00GiB (rounded to 4294967296)requested by op gradient_tape/model/conv3d_20/Conv3D/Conv3DBackpropInputV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-01-29 22:47:28.908293: I tensorflow/core/common_runtime/bfc_allocator.cc:991] BFCAllocator dump for GPU_0_bfc
# 2023-01-29 22:47:28.908319: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (256): 	Total Chunks: 128, Chunks in use: 128. 32.0KiB allocated for chunks. 32.0KiB in use in bin. 7.4KiB client-requested in use in bin.
# 2023-01-29 22:47:28.908431: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (512): 	Total Chunks: 6, Chunks in use: 6. 3.0KiB allocated for chunks. 3.0KiB in use in bin. 3.0KiB client-requested in use in bin.
# 2023-01-29 22:47:28.908446: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1024): 	Total Chunks: 4, Chunks in use: 4. 4.5KiB allocated for chunks. 4.5KiB in use in bin. 3.5KiB client-requested in use in bin.
# 2023-01-29 22:47:28.908461: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-29 22:47:28.908475: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4096): 	Total Chunks: 9, Chunks in use: 9. 53.5KiB allocated for chunks. 53.5KiB in use in bin. 52.5KiB client-requested in use in bin.
# 2023-01-29 22:47:28.908488: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8192): 	Total Chunks: 6, Chunks in use: 6. 81.0KiB allocated for chunks. 81.0KiB in use in bin. 81.0KiB client-requested in use in bin.
# 2023-01-29 22:47:28.908504: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16384): 	Total Chunks: 10, Chunks in use: 10. 247.2KiB allocated for chunks. 247.2KiB in use in bin. 223.5KiB client-requested in use in bin.
# 2023-01-29 22:47:28.908518: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (32768): 	Total Chunks: 6, Chunks in use: 6. 324.0KiB allocated for chunks. 324.0KiB in use in bin. 324.0KiB client-requested in use in bin.
# 2023-01-29 22:47:28.908531: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (65536): 	Total Chunks: 9, Chunks in use: 9. 874.0KiB allocated for chunks. 874.0KiB in use in bin. 840.0KiB client-requested in use in bin.
# 2023-01-29 22:47:28.908543: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (131072): 	Total Chunks: 6, Chunks in use: 6. 1.27MiB allocated for chunks. 1.27MiB in use in bin. 1.27MiB client-requested in use in bin.
# 2023-01-29 22:47:28.908627: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (262144): 	Total Chunks: 9, Chunks in use: 9. 3.41MiB allocated for chunks. 3.41MiB in use in bin. 3.28MiB client-requested in use in bin.
# 2023-01-29 22:47:28.908640: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (524288): 	Total Chunks: 6, Chunks in use: 6. 5.06MiB allocated for chunks. 5.06MiB in use in bin. 5.06MiB client-requested in use in bin.
# 2023-01-29 22:47:28.908653: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (1048576): 	Total Chunks: 3, Chunks in use: 3. 5.06MiB allocated for chunks. 5.06MiB in use in bin. 5.06MiB client-requested in use in bin.
# 2023-01-29 22:47:28.908665: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-29 22:47:28.908676: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (4194304): 	Total Chunks: 2, Chunks in use: 2. 8.00MiB allocated for chunks. 8.00MiB in use in bin. 8.00MiB client-requested in use in bin.
# 2023-01-29 22:47:28.908689: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (8388608): 	Total Chunks: 4, Chunks in use: 3. 33.99MiB allocated for chunks. 24.00MiB in use in bin. 24.00MiB client-requested in use in bin.
# 2023-01-29 22:47:28.908701: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (16777216): 	Total Chunks: 3, Chunks in use: 2. 55.00MiB allocated for chunks. 32.00MiB in use in bin. 32.00MiB client-requested in use in bin.
# 2023-01-29 22:47:28.908714: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (33554432): 	Total Chunks: 7, Chunks in use: 7. 264.00MiB allocated for chunks. 264.00MiB in use in bin. 224.00MiB client-requested in use in bin.
# 2023-01-29 22:47:28.908726: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (67108864): 	Total Chunks: 5, Chunks in use: 4. 354.00MiB allocated for chunks. 256.00MiB in use in bin. 256.00MiB client-requested in use in bin.
# 2023-01-29 22:47:28.908821: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (134217728): 	Total Chunks: 6, Chunks in use: 6. 768.00MiB allocated for chunks. 768.00MiB in use in bin. 768.00MiB client-requested in use in bin.
# 2023-01-29 22:47:28.908835: I tensorflow/core/common_runtime/bfc_allocator.cc:998] Bin (268435456): 	Total Chunks: 26, Chunks in use: 21. 36.06GiB allocated for chunks. 28.25GiB in use in bin. 28.25GiB client-requested in use in bin.
# 2023-01-29 22:47:28.908849: I tensorflow/core/common_runtime/bfc_allocator.cc:1014] Bin for 4.00GiB was 256.00MiB, Chunk State:
# 2023-01-29 22:47:28.908871: I tensorflow/core/common_runtime/bfc_allocator.cc:1020]   Size: 392.00MiB | Requested Size: 256.00MiB | in_use: 0 | bin_num: 20, prev:   Size: 128.00MiB | Requested Size: 128.00MiB | in_use: 1 | bin_num: -1, for: model/conv3d_15/Conv3D, stepid: 13309998600698374334, last_action: 94752245484573, next:   Size: 1.00GiB | Requested Size: 1.00GiB | in_use: 1 | bin_num: -1, for: model/up_sampling3d_2/concat_2, stepid: 13309998600698374334, last_action: 94752245485622, for: UNUSED, stepid: 13309998600698374334, last_action: 94752245488170
# 2023-01-29 22:47:28.908898: I tensorflow/core/common_runtime/bfc_allocator.cc:1020]   Size: 512.00MiB | Requested Size: 256.00MiB | in_use: 0 | bin_num: 20, prev:   Size: 64.00MiB | Requested Size: 32.00MiB | in_use: 1 | bin_num: -1, for: model/conv3d_7/Conv3D, stepid: 13309998600698374334, last_action: 94752245483592, next:   Size: 256.00MiB | Requested Size: 256.00MiB | in_use: 1 | bin_num: -1, for: model/ArithmeticOptimizer/ReorderCastLikeAndValuePreserving_float_Cast, stepid: 13309998600698374334, last_action: 94752245483536, for: UNUSED, stepid: 13309998600698374334, last_action: 94752245488157
# 2023-01-29 22:47:28.908917: I tensorflow/core/common_runtime/bfc_allocator.cc:1020]   Size: 1.51GiB | Requested Size: 256.00MiB | in_use: 0 | bin_num: 20, prev:   Size: 512.00MiB | Requested Size: 512.00MiB | in_use: 1 | bin_num: -1, for: model/conv3d_18/Conv3D, stepid: 13309998600698374334, last_action: 94752245485766, next:   Size: 4.00GiB | Requested Size: 4.00GiB | in_use: 1 | bin_num: -1, for: model/up_sampling3d_3/concat_2, stepid: 13309998600698374334, last_action: 94752245487839, for: UNUSED, stepid: 13309998600698374334, last_action: 94752245488158
# 2023-01-29 22:47:28.909013: I tensorflow/core/common_runtime/bfc_allocator.cc:1020]   Size: 2.00GiB | Requested Size: 2.00GiB | in_use: 0 | bin_num: 20, prev:   Size: 4.00GiB | Requested Size: 4.00GiB | in_use: 1 | bin_num: -1, for: model/concatenate_3/concat, stepid: 13309998600698374334, last_action: 94752245488103, next:   Size: 2.00GiB | Requested Size: 2.00GiB | in_use: 1 | bin_num: -1, for: gradient_tape/model/conv3d_21/Conv3D/Conv3DBackpropInputV2, stepid: 13309998600698374334, last_action: 94752245488177, for: UNUSED, stepid: 13309998600698374334, last_action: 94752245488187
I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f798c35f300 of size 536870912 by op model/conv3d_16/Conv3D action_count 94752245485753 step 13309998600698374334 next 297
# 2023-01-29 22:47:28.911978: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f79ac35f300 of size 1073741824 by op model/concatenate_2/concat action_count 94752245485760 step 13309998600698374334 next 290
# 2023-01-29 22:47:28.911990: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f79ec35f300 of size 536870912 by op model/conv3d_17/Conv3D action_count 94752245485761 step 13309998600698374334 next 291
# 2023-01-29 22:47:28.912001: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7a0c35f300 of size 536870912 by op model/conv3d_18/Conv3D action_count 94752245485766 step 13309998600698374334 next 302
# 2023-01-29 22:47:28.912013: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f7a2c35f300 of size 1619001344 by op UNUSED action_count 94752245488158 step 13309998600698374334 next 251
# 2023-01-29 22:47:28.912025: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7a8cb5f300 of size 4294967296 by op model/up_sampling3d_3/concat_2 action_count 94752245487839 step 13309998600698374334 next 494
# 2023-01-29 22:47:28.912037: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7b8cb5f300 of size 2147483648 by op model/conv3d_19/Conv3D action_count 94752245488098 step 13309998600698374334 next 227
# 2023-01-29 22:47:28.912049: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7c0cb5f300 of size 4294967296 by op model/concatenate_3/concat action_count 94752245488103 step 13309998600698374334 next 229
# 2023-01-29 22:47:28.912061: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f7d0cb5f300 of size 2147483648 by op UNUSED action_count 94752245488187 step 13309998600698374334 next 250
# 2023-01-29 22:47:28.912072: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7d8cb5f300 of size 2147483648 by op gradient_tape/model/conv3d_21/Conv3D/Conv3DBackpropInputV2 action_count 94752245488177 step 13309998600698374334 next 248
# 2023-01-29 22:47:28.912083: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] InUse at 7f7e0cb5f300 of size 4294967296 by op gradient_tape/model/conv3d_20/Conv3D/Conv3DBackpropInputV2 action_count 94752245488190 step 13309998600698374334 next 236
# 2023-01-29 22:47:28.912094: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Free  at 7f7f0cb5f300 of size 3671919872 by op UNUSED action_count 94752245488184 step 13309998600698374334 next 18446744073709551615
# 2023-01-29 22:47:28.912104: I tensorflow/core/common_runtime/bfc_allocator.cc:1051]      Summary of in-use Chunks by size:
# 2023-01-29 22:47:28.912117: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 128 Chunks of size 256 totalling 32.0KiB
# 2023-01-29 22:47:28.912128: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 6 Chunks of size 512 totalling 3.0KiB
# 2023-01-29 22:47:28.912139: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 2 Chunks of size 1024 totalling 2.0KiB
# 2023-01-29 22:47:28.912150: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 2 Chunks of size 1280 totalling 2.5KiB
# 2023-01-29 22:47:28.912162: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 3 Chunks of size 4096 totalling 12.0KiB
# 2023-01-29 22:47:28.912173: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 5 Chunks of size 6912 totalling 33.8KiB
# 2023-01-29 22:47:28.912183: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 7936 totalling 7.8KiB
# 2023-01-29 22:47:28.912194: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 6 Chunks of size 13824 totalling 81.0KiB
# 2023-01-29 22:47:28.912205: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 16384 totalling 16.0KiB
# 2023-01-29 22:47:28.912216: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 20736 totalling 20.2KiB
# 2023-01-29 22:47:28.912227: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 22528 totalling 22.0KiB
# 2023-01-29 22:47:28.912240: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 7 Chunks of size 27648 totalling 189.0KiB
# 2023-01-29 22:47:28.912251: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 6 Chunks of size 55296 totalling 324.0KiB
# 2023-01-29 22:47:28.912262: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 65536 totalling 64.0KiB
# 2023-01-29 22:47:28.912273: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 75776 totalling 74.0KiB
# 2023-01-29 22:47:28.912285: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 90112 totalling 88.0KiB
# 2023-01-29 22:47:28.912297: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 6 Chunks of size 110592 totalling 648.0KiB
# 2023-01-29 22:47:28.912308: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 6 Chunks of size 221184 totalling 1.27MiB
# 2023-01-29 22:47:28.912319: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 262144 totalling 256.0KiB
# 2023-01-29 22:47:28.912330: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 303104 totalling 296.0KiB
# 2023-01-29 22:47:28.912340: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 360448 totalling 352.0KiB
# 2023-01-29 22:47:28.912351: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 6 Chunks of size 442368 totalling 2.53MiB
# 2023-01-29 22:47:28.912362: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 6 Chunks of size 884736 totalling 5.06MiB
# 2023-01-29 22:47:28.912373: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 3 Chunks of size 1769472 totalling 5.06MiB
# 2023-01-29 22:47:28.912384: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 2 Chunks of size 4194304 totalling 8.00MiB
# 2023-01-29 22:47:28.912395: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 3 Chunks of size 8388608 totalling 24.00MiB
# 2023-01-29 22:47:28.912406: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 2 Chunks of size 16777216 totalling 32.00MiB
# 2023-01-29 22:47:28.912417: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 5 Chunks of size 33554432 totalling 160.00MiB
# 2023-01-29 22:47:28.912427: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 41943040 totalling 40.00MiB
# 2023-01-29 22:47:28.912439: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 1 Chunks of size 67108608 totalling 64.00MiB
# 2023-01-29 22:47:28.912450: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 4 Chunks of size 67108864 totalling 256.00MiB
# 2023-01-29 22:47:28.912460: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 6 Chunks of size 134217728 totalling 768.00MiB
# 2023-01-29 22:47:28.912471: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 5 Chunks of size 268435456 totalling 1.25GiB
# 2023-01-29 22:47:28.912482: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 6 Chunks of size 536870912 totalling 3.00GiB
# 2023-01-29 22:47:28.912493: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 2 Chunks of size 1073741824 totalling 2.00GiB
# 2023-01-29 22:47:28.912504: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 5 Chunks of size 2147483648 totalling 10.00GiB
# 2023-01-29 22:47:28.912515: I tensorflow/core/common_runtime/bfc_allocator.cc:1054] 3 Chunks of size 4294967296 totalling 12.00GiB
# 2023-01-29 22:47:28.912525: I tensorflow/core/common_runtime/bfc_allocator.cc:1058] Sum Total of in-use chunks: 29.59GiB
# 2023-01-29 22:47:28.912536: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] total_region_allocated_bytes_: 40291729408 memory_limit_: 40291729408 available bytes: 0 curr_region_allocation_bytes_: 80583458816
# 2023-01-29 22:47:28.912551: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Stats:
# Limit:                     40291729408
# InUse:                     31768062976
# MaxInUse:                  36405900544
# NumAllocs:                        5099
# MaxAllocSize:               4345446656
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-01-29 22:47:28.912578: W tensorflow/core/common_runtime/bfc_allocator.cc:467] *_*************************************___****************************____*****************_________
# 2023-01-29 22:47:28.912607: W tensorflow/core/framework/op_kernel.cc:1767] OP_REQUIRES failed at conv_grad_ops_3d.cc:1481 : Resource exhausted: OOM when allocating tensor with shape[2,16,128,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 history = m.fit(train_dataset, epochs=1000)
#
# File ~/miniconda3/envs/CTF25/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py:1183, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1176 with trace.Trace(
#    1177     'train',
#    1178     epoch_num=epoch,
#    1179     step_num=step,
#    1180     batch_size=batch_size,
#    1181     _r=1):
#    1182   callbacks.on_train_batch_begin(step)
# -> 1183   tmp_logs = self.train_function(iterator)
#    1184   if data_handler.should_sync:
#    1185     context.async_wait()
#
# File ~/miniconda3/envs/CTF25/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:889, in Function.__call__(self, *args, **kwds)
#     886 compiler = "xla" if self._jit_compile else "nonXla"
#     888 with OptionalXlaContext(self._jit_compile):
# --> 889   result = self._call(*args, **kwds)
#     891 new_tracing_count = self.experimental_get_tracing_count()
#     892 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/miniconda3/envs/CTF25/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:917, in Function._call(self, *args, **kwds)
#     914   self._lock.release()
#     915   # In this case we have created variables on the first call, so we run the
#     916   # defunned version which is guaranteed to never create variables.
# --> 917   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918 elif self._stateful_fn is not None:
#     919   # Release the lock early so that multiple threads can perform the call
#     920   # in parallel.
#     921   self._lock.release()
#
# File ~/miniconda3/envs/CTF25/lib/python3.9/site-packages/tensorflow/python/eager/function.py:3023, in Function.__call__(self, *args, **kwargs)
#    3020 with self._lock:
#    3021   (graph_function,
#    3022    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023 return graph_function._call_flat(
#    3024     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~/miniconda3/envs/CTF25/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1960, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1956 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1957 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1958     and executing_eagerly):
#    1959   # No tape is watching; skip to running the function.
# -> 1960   return self._build_call_outputs(self._inference_function.call(
#    1961       ctx, args, cancellation_manager=cancellation_manager))
#    1962 forward_backward = self._select_forward_and_backward_functions(
#    1963     args,
#    1964     possible_gradient_type,
#    1965     executing_eagerly)
#    1966 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/miniconda3/envs/CTF25/lib/python3.9/site-packages/tensorflow/python/eager/function.py:591, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     589 with _InterpolateFunctionError(self):
#     590   if cancellation_manager is None:
# --> 591     outputs = execute.execute(
#     592         str(self.signature.name),
#     593         num_outputs=self._num_outputs,
#     594         inputs=args,
#     595         attrs=attrs,
#     596         ctx=ctx)
#     597   else:
#     598     outputs = execute.execute_with_cancellation(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#    (...)
#     603         ctx=ctx,
#     604         cancellation_manager=cancellation_manager)
#
# File ~/miniconda3/envs/CTF25/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[2,16,128,512,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradient_tape/model/conv3d_20/Conv3D/Conv3DBackpropInputV2 (defined at tmp/ipykernel_2847566/756460377.py:1) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#  [Op:__inference_train_function_17038]
#
# Function call stack:
# train_function
